# %% [markdown]
# Milvus is an opensource vector
#
# Quickstart guide - https://milvus.io/docs/quickstart.md
#
# Follow the steps here to setup locally
#
# Milvus cluster locally on docker - https://milvus.io/docs/v2.0.x/install_cluster-docker.md
#
# pip install -U pymilvus
#
#
# Setup UI for milvus -
#
# docker run -p 8000:3000 -e HOST_URL=http://localhost:8000 -e MILVUS_URL=localhost:19530 zilliz/attu:latest
# https://milvus.io/docs/v2.0.x/attu_install-docker.md

# %%
from pymilvus import MilvusClient

client = MilvusClient("milvus_demo.db")
# Out:
# Failed to create new connection using: db1988fbea4d4c7ea5011209b8167011
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 3
#       1 from pymilvus import MilvusClient
# ----> 3 client = MilvusClient("milvus_demo.db")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pymilvus\milvus_client\milvus_client.py:60, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      48 """A client for the common Milvus use case.
#      49
#      50 This client attempts to hide away the complexity of using Pymilvus. In a lot ofcases what
#    (...)
#      58         to None.
#      59 """
# ---> 60 self._using = self._create_connection(
#      61     uri, user, password, db_name, token, timeout=timeout, **kwargs
# ...
